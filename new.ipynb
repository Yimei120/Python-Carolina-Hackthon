# %%
import pandas as pd
c = pd.read_csv('2013-community-survey-data.csv',encoding="utf-8", sep=';')

s=[]
for i in c.columns:
    if 'Q5' in i:
        s.append(i)
        
cs_2013=c[s]
cs_2013

cs_2013.columns=['Q5a','Q5b','Q5c','Q5d','Q5e','Q5f','Q5g','Q5h','Q5i']
s1=pd.DataFrame()
s1['Q5a']=(cs_2013.Q5a.value_counts())
s1['Q5b']=(cs_2013.Q5b.value_counts())
s1['Q5c']=(cs_2013.Q5c.value_counts())
s1['Q5d']=(cs_2013.Q5d.value_counts())
s1['Q5e']=(cs_2013.Q5e.value_counts())
s1['Q5f']=(cs_2013.Q5f.value_counts())
s1['Q5g']=(cs_2013.Q5g.value_counts())
s1['Q5h']=(cs_2013.Q5h.value_counts())
s1['Q5i']=(cs_2013.Q5i.value_counts())

# %%
#s1 = s1.transpose()
#s1
# Out:
#      Satisfied  Very Satisfied  Neutral  Don't Know  Dissatisfied  \
# Q5a        294             259       56          42            19
# Q5b        264             181      156          22            39
# Q5c        262             150      131          88            36
# Q5d        236             201       68         158            10
# Q5e        255             131      147          54            69
# Q5f        140             109      110         301            10
# Q5g        308             201       82          59            18
# Q5h        239             229       84          85            24
# Q5i        305             205      109           6            42
#
#      Very Dissatisfied
# Q5a                  5
# Q5b                 13
# Q5c                  7
# Q5d                  1
# Q5e                 19
# Q5f                  1
# Q5g                  6
# Q5h                 14
# Q5i                  5

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# my_colors = [(x/5.0, x/10.0, 0.6) for x in range(len(s1))] 
colors = ['wheat','orange','darkorange','tan',"goldenrod",'darkgoldenrod']
s1.plot(kind='bar', stacked=True, color=colors,figsize=(15,10))
plt.legend(loc = 'best')
plt.show()

# %%
cs_2011=pd.read_csv('2011-community-survey-data.csv',encoding="utf-8", sep=';')
cs_2011
# Out:
#     Q1a Overall quality of services provided Q1b Public safety services  \
# 0                                  Satisfied             Very Satisfied
# 1                                  Satisfied                  Satisfied
# 2                             Very Satisfied             Very Satisfied
# 3                                    Neutral                  Satisfied
# 4                             Very Satisfied                  Satisfied
# 5                                    Neutral                    Neutral
# 6                                  Satisfied                  Satisfied
# 7                                    Neutral                  Satisfied
# 8                                  Satisfied                  Satisfied
# 9                                  Satisfied             Very Satisfied
# 10                            Very Satisfied             Very Satisfied
# 11                                 Satisfied                  Satisfied
# ...

# %%
s=[]
for i in cs_2011.columns:
    if 'Q5' in i:
        s.append(i)

cs_2011=cs_2011[s]
cs_2011.columns=['Q5a','Q5b','Q5c','Q5d','Q5e','Q5f','Q5g','Q5h','Q5i']
cs_2011.head()
# Out:
#               Q5a             Q5b             Q5c             Q5d  \
# 0  Very Satisfied       Satisfied  Very Satisfied  Very Satisfied
# 1       Satisfied  Very Satisfied       Satisfied       Satisfied
# 2  Very Satisfied  Very Satisfied  Very Satisfied    Dissatisfied
# 3       Satisfied         Neutral       Satisfied      Don't Know
# 4         Neutral       Satisfied       Satisfied  Very Satisfied
#
#               Q5e             Q5f             Q5g             Q5h  \
# 0  Very Satisfied  Very Satisfied  Very Satisfied  Very Satisfied
# 1       Satisfied       Satisfied       Satisfied       Satisfied
# 2  Very Satisfied  Very Satisfied  Very Satisfied  Very Satisfied
# 3       Satisfied      Don't Know       Satisfied      Don't Know
# 4  Very Satisfied      Don't Know       Satisfied       Satisfied
#
#               Q5i
# 0  Very Satisfied
# 1       Satisfied
# 2  Very Satisfied
# 3       Satisfied
# 4  Very Satisfied

# %%
s2=pd.DataFrame()
s2['Q5a']=(cs_2011.Q5a.value_counts())
s2['Q5b']=(cs_2011.Q5b.value_counts())
s2['Q5c']=(cs_2011.Q5c.value_counts())
s2['Q5d']=(cs_2011.Q5d.value_counts())
s2['Q5e']=(cs_2011.Q5e.value_counts())
s2['Q5f']=(cs_2011.Q5f.value_counts())
s2['Q5g']=(cs_2011.Q5g.value_counts())
s2['Q5h']=(cs_2011.Q5h.value_counts())
s2['Q5i']=(cs_2011.Q5i.value_counts())
s2
# Out:
#                    Q5a  Q5b  Q5c  Q5d  Q5e  Q5f  Q5g  Q5h  Q5i
# Satisfied          251  245  246  180  228  130  268  221  276
# Very Satisfied     220  150  133  185  142   95  174  202  185
# Neutral             68  126   98   56  118   75   90   65   96
# Don't Know          44   22   87  169   62  290   49   80   14
# Dissatisfied        15   54   31   14   41   12   19   21   34
# Very Dissatisfied    9   10   12    3   16    5    7   18    2

# %%
cs_2015=pd.read_csv('q5-public-safety-police-services.csv',encoding="utf-8", sep=';')
s=[]
for i in cs_2015.columns:
    if 'Q5' in i:
        s.append(i)
        
cs_2015=cs_2015[s]
cs_2015.columns=['Q5a','Q5b','Q5c','Q5d','Q5e','Q5f','Q5g','Q5h','Q5i']
cs_2015.head()
# Out:
#     Q5-5. Overall quality of local police protection  \
# 0                                     Very Satisfied
# 1                                     Very Satisfied
# 2                                     Very Satisfied
# 3                                     Very Satisfied
# 4                                            Neutral
# 5                                          Satisfied
# 6                                     Very Satisfied
# 7                                     Very Satisfied
# 8                                     Very Satisfied
# 9                                     Very Satisfied
# 10                                         Satisfied
# 11                                         Satisfied
# 12                                    Very Satisfied
# 13                                         Satisfied
# 14                                    Very Satisfied
# 15                                           Neutral
# 16                                         Satisfied
# ...

# %%
s3=pd.DataFrame()
s3['Q5a']=(cs_2015.Q5a.value_counts())
s3['Q5b']=(cs_2015.Q5b.value_counts())
s3['Q5c']=(cs_2015.Q5c.value_counts())
s3['Q5d']=(cs_2015.Q5d.value_counts())
s3['Q5e']=(cs_2015.Q5e.value_counts())
s3['Q5f']=(cs_2015.Q5f.value_counts())
s3['Q5g']=(cs_2015.Q5g.value_counts())
s3['Q5h']=(cs_2015.Q5h.value_counts())
s3['Q5i']=(cs_2015.Q5i.value_counts())
s3
# Out:
#                    Q5a  Q5b  Q5c  Q5d  Q5e    Q5f  Q5g  Q5h  Q5i
# Satisfied          176  161  165  144  152   86.0  200  146  198
# Very Satisfied     143   97   76  126   87   64.0  108  143  126
# Neutral             49   99   86   42   81   65.0   59   51   48
# Don't Know          30   17   58   88   27  185.0   32   51    7
# Dissatisfied         7   26   16    7   45    7.0    7   15   27
# Very Dissatisfied    4    9    8    1   16    NaN    3    3    3

# %%
combined=pd.DataFrame()i
combined['2011']=s2.Q5g
combined['2013']=s1.Q5g
combined['2015']=s3.Q5g
combined=combined.transpose()
combined
# Out:
#       Satisfied  Very Satisfied  Neutral  Don't Know  Dissatisfied  \
# 2011        268             174       90          49            19
# 2013        308             201       82          59            18
# 2015        200             108       59          32             7
#
#       Very Dissatisfied
# 2011                  7
# 2013                  6
# 2015                  3

# %%
colors = ['wheat','orange','darkorange','tan',"goldenrod",'darkgoldenrod']
combined.plot(kind='bar', stacked=True, color=colors,figsize=(15,10))
plt.legend(loc = 'best')
plt.show()

# %%
combined=combined.transpose()
percentage=combined.iloc[:, :].apply(lambda x: x / x.sum())
percentage=percentage.transpose()
percentage
# Out:
#       Satisfied  Very Satisfied   Neutral  Don't Know  Dissatisfied  \
# 2011   0.441516        0.286656  0.148270    0.080725      0.031301
# 2013   0.456973        0.298220  0.121662    0.087537      0.026706
# 2015   0.488998        0.264059  0.144254    0.078240      0.017115
#
#       Very Dissatisfied
# 2011           0.011532
# 2013           0.008902
# 2015           0.007335

# %%
colors = ['wheat','orange','darkorange','tan',"goldenrod",'darkgoldenrod']
percentage.plot(kind='bar',stacked=True, color=colors,figsize=(15,10))
plt.legend(loc = 'best')
plt.ylabel('percentage')
plt.show()

# %%
per_satis=percentage['Satisfied']

plt.plot( per_satis.index, per_satis.values, marker='o', markerfacecolor='yellow', markersize=12, color='orange', linewidth=4)
plt.ylabel('Percentage of Satisfaction')
# Out:
# Text(0, 0.5, 'Percentage of Satisfaction')

# %%
per_dissatis=percentage['Dissatisfied']

plt.plot( per_dissatis.index, per_dissatis.values, marker='o', markerfacecolor='skyblue', markersize=12, color='blue', linewidth=4)
plt.ylabel('Percentage of Dissatisfaction')
# Out:
# Text(0, 0.5, 'Percentage of Dissatisfaction')

# %%
safety=pd.DataFrame()
safety['2011']=s2.Q5h
safety['2013']=s1.Q5h
safety['2015']=s3.Q5h
safety=safety.transpose()
safety
# Out:
#       Satisfied  Very Satisfied  Neutral  Don't Know  Dissatisfied  \
# 2011        221             202       65          80            21
# 2013        239             229       84          85            24
# 2015        146             143       51          51            15
#
#       Very Dissatisfied
# 2011                 18
# 2013                 14
# 2015                  3

# %%
safety=safety.transpose()
percentage_1=safety.iloc[:, :].apply(lambda x: x / x.sum())
percentage_1=percentage_1.transpose()
percentage_1
# Out:
#       Satisfied  Very Satisfied   Neutral  Don't Know  Dissatisfied  \
# 2011   0.364086        0.332784  0.107084    0.131796      0.034596
# 2013   0.354074        0.339259  0.124444    0.125926      0.035556
# 2015   0.356968        0.349633  0.124694    0.124694      0.036675
#
#       Very Dissatisfied
# 2011           0.029654
# 2013           0.020741
# 2015           0.007335

# %%
per_satis_1=percentage_1['Satisfied']

plt.plot( per_satis_1.index, per_satis_1.values, marker='o', markerfacecolor='yellow', markersize=12, color='orange', linewidth=4)
plt.ylabel('Percentage of Satisfaction')
# Out:
# Text(0, 0.5, 'Percentage of Satisfaction')

# %%
per_satis_1=percentage_1['Dissatisfied']

plt.plot( per_satis_1.index, per_satis_1.values, marker='o', markerfacecolor='skyblue', markersize=12, color='blue', linewidth=4)
plt.ylabel('Percentage of Dissatisfaction')
# Out:
# Text(0, 0.5, 'Percentage of Dissatisfaction')
